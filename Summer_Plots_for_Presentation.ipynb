# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'Summer Hot 100.csv'
summer_charts = pd.read_csv(path)
summer_charts.head()
# Out:
#    Unnamed: 0      Summer Anthem  \
# 0           0          Despacito
# 1           1  Thats What I Like
# 2           2         Im The One
# 3           3       Shape Of You
# 4           4            Humble.
#
#                                               Artist  \
# 0   Luis Fonsi & Daddy Yankee Featuring Justin Bi...
# 1                                         Bruno Mars
# 2   DJ Khaled Featuring Justin Bieber, Quavo, Cha...
# 3                                         Ed Sheeran
# 4                                     Kendrick Lamar
#
#                                Song URI  Date  Danceability  Energy  \
# 0                                   NaN  2017           NaN     NaN
# 1  spotify:track:0KKkJNfGyhkQ5aFogxQAPU  2017         0.853   0.560
# 2                                   NaN  2017           NaN     NaN
# 3  spotify:track:0FE9t6xYkqWXU2ahLh6D8X  2017         0.825   0.652
# 4  spotify:track:7KXjTSCq5nL1LoYtL7XAwS  2017         0.904   0.611
#
# ...

# %%
# columns = ['Winter Anthem', 
#             'Artist',
#             'Song URI',
#             'Date',
#             'Lyrics',
#             'Sentiment',
#             'Danceability',
#             'Energy',
#             'Acousticness',
#             'Valence',
#             'Tempo',
#             'Instrumentalness']

# %% [markdown]
# # Summer Anthem

# %%
# Artist vs Year:
# Scatter Plot with Regression
# library & dataset

# %%
# Song URI vs Year:

# %%
# Date vs Year:

# %%
# Lyrics vs Year:

# %%
# Sentiment vs Date:

# %%
# Summer: Danceability vs Date:
import pandas as pd
import seaborn as sns

df = pd.read_csv('Summer Hot 100.csv')
#df = pd.DataFrame('Summer Hot 100.csv')
 
df = df.plot.scatter(x='Danceability', y='Date', color='red');


# use the function regplot to make a scatterplot
#sns.regplot(x=df["Artist"], y=df["Date"])
#sns.plt.show()
 
# Without regression fit:
#sns.regplot(x=df["Artist"], y=df["Date"], fit_reg=False)
#sns.plt.show()
#df.keys()

# %%
# Summer: Energy vs Danceability:
import pandas as pd
import seaborn as sns

df = pd.read_csv('Summer Hot 100.csv')
#df = pd.DataFrame('Summer Hot 100.csv')
 
df = df.plot.scatter(x='Energy', y='Danceability', color='red');


# use the function regplot to make a scatterplot
#sns.regplot(x=df["Artist"], y=df["Date"])
#sns.plt.show()
 
# Without regression fit:
#sns.regplot(x=df["Artist"], y=df["Date"], fit_reg=False)
#sns.plt.show()
#df.keys()

# %%
# Acousticness vs Energy:
import pandas as pd
import seaborn as sns

df = pd.read_csv('Summer Hot 100.csv')

#df = pd.DataFrame('Summer Hot 100.csv')
 

# use the function regplot to make a scatterplot
#sns.regplot(x=df["Artist"], y=df["Date"])
#sns.plt.show()
 
# Without regression fit:
#sns.regplot(x=df["Artist"], y=df["Date"], fit_reg=False)
#sns.plt.show()
#df.keys()

# %%
df.head()
# Out:
#    Unnamed: 0      Summer Anthem  \
# 0           0          Despacito
# 1           1  Thats What I Like
# 2           2         Im The One
# 3           3       Shape Of You
# 4           4            Humble.
#
#                                               Artist  \
# 0   Luis Fonsi & Daddy Yankee Featuring Justin Bi...
# 1                                         Bruno Mars
# 2   DJ Khaled Featuring Justin Bieber, Quavo, Cha...
# 3                                         Ed Sheeran
# 4                                     Kendrick Lamar
#
#                                Song URI  Date  Danceability  Energy  \
# 0                                   NaN  2017           NaN     NaN
# 1  spotify:track:0KKkJNfGyhkQ5aFogxQAPU  2017         0.853   0.560
# 2                                   NaN  2017           NaN     NaN
# 3  spotify:track:0FE9t6xYkqWXU2ahLh6D8X  2017         0.825   0.652
# 4  spotify:track:7KXjTSCq5nL1LoYtL7XAwS  2017         0.904   0.611
#
# ...

# %%
# Summer: Date vs Acousticness
plt.bar(df['Date'], df['Acousticness'], color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-44cae37d9e5a> in <module>()
#       1 # Summer: Date vs Acousticness
# ----> 2 plt.bar(df['Date'], df['Acousticness'], color='red')
#       3 plt.show()
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
# Summer: Valence vs Tempo:
import pandas as pd
import seaborn as sns

df = pd.read_csv('Summer Hot 100.csv')
#df = pd.DataFrame('Summer Hot 100.csv')
 
df = df.plot.scatter(x='Valence', y='Tempo', color='red');


# use the function regplot to make a scatterplot
#sns.regplot(x=df["Artist"], y=df["Date"])
#sns.plt.show()
 
# Without regression fit:
#sns.regplot(x=df["Artist"], y=df["Date"], fit_reg=False)
#sns.plt.show()
#df.keys()

# %%
# Tempo vs Energy
import pandas as pd
import seaborn as sns

df = pd.read_csv('Summer Hot 100.csv')
#df = pd.DataFrame('Summer Hot 100.csv')
 
df = df.plot.scatter(x='Tempo', y='Energy', color='red');


# use the function regplot to make a scatterplot
#sns.regplot(x=df["Artist"], y=df["Date"])
#sns.plt.show()
 
# Without regression fit:
#sns.regplot(x=df["Artist"], y=df["Date"], fit_reg=False)
#sns.plt.show()
#df.keys()

# %%
# Instrumentalness vs Energy:
import pandas as pd
import seaborn as sns

df = pd.read_csv('Summer Hot 100.csv')
#df = pd.DataFrame('Summer Hot 100.csv')
 
df = df.plot.scatter(x='Instrumentalness', y='Energy', color='red');


# use the function regplot to make a scatterplot
#sns.regplot(x=df["Artist"], y=df["Date"])
#sns.plt.show()
 
# Without regression fit:
#sns.regplot(x=df["Artist"], y=df["Date"], fit_reg=False)
#sns.plt.show()
#df.keys()

# %%
# Summer: Date vs Energy
plt.bar(summer_charts ['Date'], summer_charts['Energy'], color='red')
plt.savefig('Summer_Energy')
plt.show()

# %%
# Summer: Date vs Tempo
plt.bar(summer_charts ['Date'], summer_charts['Tempo'], color='red')
plt.savefig('Summer_Tempo')
plt.show()

# %%
# Summer: Date vs Valence
plt.bar(summer_charts ['Date'], summer_charts['Valence'], color='red')
plt.savefig('Summer_Valence')
plt.show()

# %%
# Summer: Date vs Danceability
plt.bar(summer_charts ['Date'], summer_charts['Danceability'], color='red')
plt.savefig('Summer_Danceability')
plt.show()

# %%
# Summer: Date vs Acousticness
plt.bar(summer_charts ['Date'], summer_charts['Acousticness'], color='red')
plt.savefig('Summer_Acousticness')
plt.show()

# %%
# Summer: Date vs Instrumentalness
plt.bar(summer_charts ['Date'], summer_charts['Instrumentalness'], color='red')
plt.savefig('Summer_Instrumentalness')
plt.show()

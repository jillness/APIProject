# %%
from config import spotify_client_ID, spotify_client_secret, my_spotify_uri, weather_api, my_redirect_url, username, scope
from spotipy.oauth2 import SpotifyClientCredentials
from json.decoder import JSONDecodeError

import datetime 
import requests
import spotipy
import pprint
import sys
import re
import os
import pandas as pd
import spotipy.util as util
import json
import billboard
import time

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
try:
    util.prompt_for_user_token(username, scope, client_id=spotify_client_ID,client_secret=spotify_client_secret,redirect_uri=my_redirect_url)
except (AttributeError, JSONDecodeError):
    os.remove(f".cache-{username}")
    token = util.prompt_for_user_token(username, scope, client_id=spotify_client_ID,client_secret=spotify_client_secret,redirect_uri=my_redirect_url)

# %%
token = util.oauth2.SpotifyClientCredentials(client_id= spotify_client_ID, client_secret=spotify_client_secret )

cache_token = token.get_access_token()
spotify = spotipy.Spotify(cache_token)

# %%
year = datetime.datetime.today().year
years = list(range(year, year - 40, -1))

summer_charts = []
winter_charts =[]
summer_chart_date = []
winter_chart_date = []

for year in years:
    summer_chart = billboard.ChartData(f'hot-100/{year}-06-20')
    winter_chart = billboard.ChartData(f'hot-100/{year}-12-20')

    for song in summer_chart:
        summer_chart_date.append(year)
    for song in winter_chart:
        winter_chart_date.append(year)
        
    summer_charts.append(summer_chart)
    winter_charts.append(winter_chart)

# %%
print(len(summer_chart_date))
# Out:
# 3900

# %%
# Split chart name into Song / Artist lists

summer_songs = []
winter_songs = []
summer_artists = []
winter_artists = []

for chart in summer_charts:
    for entry in chart:
        entry = str(entry)
        temp = re.split(r"(' by)", entry)
        song = temp[0].replace("'","")
        summer_songs.append(song)
        singer = temp[2]
        summer_artists.append(singer)

for chart in winter_charts:
    for entry in chart:
        entry = str(entry)
        temp = re.split(r"(' by)", entry)
        song = temp[0].replace("'","")
        winter_songs.append(song)
        singer = temp[2]
        winter_artists.append(singer)

# %%
charts_df = pd.DataFrame(list(zip(summer_songs, summer_artists, summer_chart_date, winter_songs, winter_artists, winter_chart_date)), 
                        columns =['summer song', 'summer artist', 'year summer', 'winter song', 'winter artist', 'year winter'])
charts_df.to_csv('Hot 100 billboard.csv')
len(charts_df)
# Out:
# 3900

# %%
# Retrieve audio features and lyrics of SUMMER songs

summer_uri_list = []
summer_lyrics = []
summer_sentiments = []

n = 0 

for song, artist in zip(summer_songs, summer_artists):
    
    query = spotify.search(f'{song} {artist}')

    #Retrieve song URI
    try:
        song_uri = query['tracks']['items'][0]['uri']
    except:
        song_uri = 'N/A'
    summer_uri_list.append(song_uri)
    n +=1
    
    #Retrieve and clean lyrics
    url = f"https://api.lyrics.ovh/v1/{artist}/{song}"
    try:
        words = requests.get(url).json()
        words = words['lyrics']
        words = words.replace('\n', ' ')
    except: 
        words = 'N/A'

    #Analyze sentiment of lyrics
    results = analyzer.polarity_scores(words)
    compound = results["compound"]
    
    summer_sentiments.append(compound)
        
    summer_lyrics.append(words)
    
    time.sleep(.3)
    
    print('\n>> processing No '+ str(n) + ' in summer anthems ')
# Out:
# >> processing No 1 in summer anthems
#
# >> processing No 2 in summer anthems
#
# >> processing No 3 in summer anthems
#
# >> processing No 4 in summer anthems
#
# >> processing No 5 in summer anthems
#
# >> processing No 6 in summer anthems
#
# >> processing No 7 in summer anthems
#
# >> processing No 8 in summer anthems
#
# >> processing No 9 in summer anthems
#
# >> processing No 10 in summer anthems
#
# >> processing No 11 in summer anthems
#
# >> processing No 12 in summer anthems
#
# >> processing No 13 in summer anthems
#
# >> processing No 14 in summer anthems
#
# >> processing No 15 in summer anthems
#
# >> processing No 16 in summer anthems
#
# >> processing No 17 in summer anthems
#
# >> processing No 18 in summer anthems
#
# >> processing No 19 in summer anthems
#
# >> processing No 20 in summer anthems
#
# >> processing No 21 in summer anthems
#
# >> processing No 22 in summer anthems
#
# >> processing No 23 in summer anthems
#
# >> processing No 24 in summer anthems
#
# >> processing No 25 in summer anthems
#
# >> processing No 26 in summer anthems
#
# >> processing No 27 in summer anthems
#
# >> processing No 28 in summer anthems
#
# >> processing No 29 in summer anthems
#
# >> processing No 30 in summer anthems
#
# >> processing No 31 in summer anthems
#
# >> processing No 32 in summer anthems
#
# >> processing No 33 in summer anthems
#
# >> processing No 34 in summer anthems
#
# >> processing No 35 in summer anthems
#
# >> processing No 36 in summer anthems
#
# >> processing No 37 in summer anthems
#
# >> processing No 38 in summer anthems
#
# >> processing No 39 in summer anthems
#
# >> processing No 40 in summer anthems
#
# >> processing No 41 in summer anthems
#
# >> processing No 42 in summer anthems
#
# >> processing No 43 in summer anthems
#
# >> processing No 44 in summer anthems
#
# >> processing No 45 in summer anthems
#
# >> processing No 46 in summer anthems
#
# >> processing No 47 in summer anthems
#
# >> processing No 48 in summer anthems
#
# >> processing No 49 in summer anthems
#
# >> processing No 50 in summer anthems
#
# >> processing No 51 in summer anthems
#
# >> processing No 52 in summer anthems
#
# >> processing No 53 in summer anthems
#
# >> processing No 54 in summer anthems
#
# >> processing No 55 in summer anthems
#
# >> processing No 56 in summer anthems
#
# >> processing No 57 in summer anthems
#
# >> processing No 58 in summer anthems
#
# >> processing No 59 in summer anthems
#
# >> processing No 60 in summer anthems
#
# >> processing No 61 in summer anthems
#
# >> processing No 62 in summer anthems
#
# >> processing No 63 in summer anthems
#
# >> processing No 64 in summer anthems
#
# >> processing No 65 in summer anthems
#
# >> processing No 66 in summer anthems
#
# >> processing No 67 in summer anthems
#
# >> processing No 68 in summer anthems
#
# >> processing No 69 in summer anthems
#
# >> processing No 70 in summer anthems
#
# >> processing No 71 in summer anthems
#
# >> processing No 72 in summer anthems
#
# >> processing No 73 in summer anthems
#
# >> processing No 74 in summer anthems
#
# >> processing No 75 in summer anthems
#
# >> processing No 76 in summer anthems
#
# >> processing No 77 in summer anthems
#
# >> processing No 78 in summer anthems
#
# >> processing No 79 in summer anthems
#
# >> processing No 80 in summer anthems
#
# >> processing No 81 in summer anthems
#
# >> processing No 82 in summer anthems
#
# >> processing No 83 in summer anthems
#
# >> processing No 84 in summer anthems
#
# >> processing No 85 in summer anthems
#
# >> processing No 86 in summer anthems
#
# >> processing No 87 in summer anthems
#
# >> processing No 88 in summer anthems
#
# >> processing No 89 in summer anthems
#
# >> processing No 90 in summer anthems
#
# >> processing No 91 in summer anthems
#
# >> processing No 92 in summer anthems
#
# >> processing No 93 in summer anthems
#
# >> processing No 94 in summer anthems
#
# >> processing No 95 in summer anthems
#
# >> processing No 96 in summer anthems
#
# >> processing No 97 in summer anthems
#
# >> processing No 98 in summer anthems
#
# >> processing No 99 in summer anthems
#
# >> processing No 100 in summer anthems
#
# >> processing No 101 in summer anthems
#
# >> processing No 102 in summer anthems
#
# >> processing No 103 in summer anthems
#
# >> processing No 104 in summer anthems
#
# >> processing No 105 in summer anthems
#
# >> processing No 106 in summer anthems
#
# >> processing No 107 in summer anthems
#
# >> processing No 108 in summer anthems
#
# >> processing No 109 in summer anthems
#
# >> processing No 110 in summer anthems
#
# >> processing No 111 in summer anthems
#
# >> processing No 112 in summer anthems
#
# >> processing No 113 in summer anthems
#
# >> processing No 114 in summer anthems
#
# >> processing No 115 in summer anthems
#
# >> processing No 116 in summer anthems
#
# >> processing No 117 in summer anthems
#
# >> processing No 118 in summer anthems
#
# >> processing No 119 in summer anthems
#
# >> processing No 120 in summer anthems
#
# >> processing No 121 in summer anthems
#
# >> processing No 122 in summer anthems
#
# >> processing No 123 in summer anthems
#
# >> processing No 124 in summer anthems
#
# >> processing No 125 in summer anthems
#
# >> processing No 126 in summer anthems
#
# >> processing No 127 in summer anthems
#
# >> processing No 128 in summer anthems
#
# >> processing No 129 in summer anthems
#
# >> processing No 130 in summer anthems
#
# >> processing No 131 in summer anthems
#
# >> processing No 132 in summer anthems
#
# >> processing No 133 in summer anthems
#
# >> processing No 134 in summer anthems
#
# >> processing No 135 in summer anthems
#
# >> processing No 136 in summer anthems
#
# >> processing No 137 in summer anthems
#
# >> processing No 138 in summer anthems
#
# >> processing No 139 in summer anthems
#
# >> processing No 140 in summer anthems
#
# >> processing No 141 in summer anthems
#
# >> processing No 142 in summer anthems
#
# >> processing No 143 in summer anthems
#
# >> processing No 144 in summer anthems
#
# >> processing No 145 in summer anthems
#
# >> processing No 146 in summer anthems
#
# >> processing No 147 in summer anthems
#
# >> processing No 148 in summer anthems
#
# >> processing No 149 in summer anthems
#
# >> processing No 150 in summer anthems
#
# >> processing No 151 in summer anthems
#
# >> processing No 152 in summer anthems
#
# >> processing No 153 in summer anthems
#
# >> processing No 154 in summer anthems
#
# >> processing No 155 in summer anthems
#
# >> processing No 156 in summer anthems
#
# >> processing No 157 in summer anthems
#
# >> processing No 158 in summer anthems
#
# >> processing No 159 in summer anthems
#
# >> processing No 160 in summer anthems
#
# >> processing No 161 in summer anthems
#
# >> processing No 162 in summer anthems
#
# >> processing No 163 in summer anthems
#
# >> processing No 164 in summer anthems
#
# >> processing No 165 in summer anthems
#
# >> processing No 166 in summer anthems
#
# >> processing No 167 in summer anthems
#
# >> processing No 168 in summer anthems
#
# >> processing No 169 in summer anthems
#
# >> processing No 170 in summer anthems
#
# >> processing No 171 in summer anthems
#
# >> processing No 172 in summer anthems
#
# >> processing No 173 in summer anthems
#
# >> processing No 174 in summer anthems
#
# >> processing No 175 in summer anthems
#
# >> processing No 176 in summer anthems
#
# >> processing No 177 in summer anthems
#
# >> processing No 178 in summer anthems
#
# >> processing No 179 in summer anthems
#
# >> processing No 180 in summer anthems
#
# >> processing No 181 in summer anthems
#
# >> processing No 182 in summer anthems
#
# >> processing No 183 in summer anthems
#
# >> processing No 184 in summer anthems
#
# >> processing No 185 in summer anthems
#
# >> processing No 186 in summer anthems
#
# >> processing No 187 in summer anthems
#
# >> processing No 188 in summer anthems
#
# >> processing No 189 in summer anthems
#
# >> processing No 190 in summer anthems
#
# >> processing No 191 in summer anthems
#
# >> processing No 192 in summer anthems
#
# >> processing No 193 in summer anthems
#
# >> processing No 194 in summer anthems
#
# >> processing No 195 in summer anthems
#
# >> processing No 196 in summer anthems
#
# >> processing No 197 in summer anthems
#
# >> processing No 198 in summer anthems
#
# >> processing No 199 in summer anthems
#
# >> processing No 200 in summer anthems
#
# >> processing No 201 in summer anthems
#
# >> processing No 202 in summer anthems
#
# >> processing No 203 in summer anthems
# >> processing No 204 in summer anthems
#
# >> processing No 205 in summer anthems
#
# >> processing No 206 in summer anthems
#
# >> processing No 207 in summer anthems
#
# >> processing No 208 in summer anthems
#
# >> processing No 209 in summer anthems
#
# >> processing No 210 in summer anthems
#
# >> processing No 211 in summer anthems
#
# >> processing No 212 in summer anthems
#
# >> processing No 213 in summer anthems
#
# >> processing No 214 in summer anthems
#
# >> processing No 215 in summer anthems
#
# >> processing No 216 in summer anthems
#
# >> processing No 217 in summer anthems
#
# >> processing No 218 in summer anthems
#
# >> processing No 219 in summer anthems
#
# >> processing No 220 in summer anthems
#
# >> processing No 221 in summer anthems
#
# >> processing No 222 in summer anthems
#
# >> processing No 223 in summer anthems
#
# >> processing No 224 in summer anthems
#
# >> processing No 225 in summer anthems
#
# >> processing No 226 in summer anthems
#
# >> processing No 227 in summer anthems
#
# >> processing No 228 in summer anthems
#
# >> processing No 229 in summer anthems
#
# >> processing No 230 in summer anthems
#
# >> processing No 231 in summer anthems
#
# >> processing No 232 in summer anthems
#
# >> processing No 233 in summer anthems
#
# >> processing No 234 in summer anthems
#
# >> processing No 235 in summer anthems
#
# >> processing No 236 in summer anthems
#
# >> processing No 237 in summer anthems
#
# >> processing No 238 in summer anthems
#
# >> processing No 239 in summer anthems
#
# >> processing No 240 in summer anthems
#
# >> processing No 241 in summer anthems
#
# >> processing No 242 in summer anthems
#
# >> processing No 243 in summer anthems
#
# >> processing No 244 in summer anthems
#
# >> processing No 245 in summer anthems
#
# >> processing No 246 in summer anthems
#
# >> processing No 247 in summer anthems
#
# >> processing No 248 in summer anthems
#
# >> processing No 249 in summer anthems
#
# >> processing No 250 in summer anthems
#
# >> processing No 251 in summer anthems
#
# >> processing No 252 in summer anthems
#
# >> processing No 253 in summer anthems
#
# >> processing No 254 in summer anthems
#
# >> processing No 255 in summer anthems
#
# >> processing No 256 in summer anthems
#
# >> processing No 257 in summer anthems
#
# >> processing No 258 in summer anthems
#
# >> processing No 259 in summer anthems
#
# >> processing No 260 in summer anthems
#
# >> processing No 261 in summer anthems
#
# >> processing No 262 in summer anthems
#
# >> processing No 263 in summer anthems
#
# >> processing No 264 in summer anthems
#
# >> processing No 265 in summer anthems
#
# >> processing No 266 in summer anthems
#
# >> processing No 267 in summer anthems
#
# >> processing No 268 in summer anthems
#
# >> processing No 269 in summer anthems
#
# >> processing No 270 in summer anthems
#
# >> processing No 271 in summer anthems
#
# >> processing No 272 in summer anthems
#
# >> processing No 273 in summer anthems
#
# >> processing No 274 in summer anthems
#
# >> processing No 275 in summer anthems
#
# >> processing No 276 in summer anthems
#
# >> processing No 277 in summer anthems
#
# >> processing No 278 in summer anthems
#
# >> processing No 279 in summer anthems
#
# >> processing No 280 in summer anthems
#
# >> processing No 281 in summer anthems
#
# >> processing No 282 in summer anthems
#
# >> processing No 283 in summer anthems
#
# >> processing No 284 in summer anthems
#
# >> processing No 285 in summer anthems
#
# >> processing No 286 in summer anthems
#
# >> processing No 287 in summer anthems
#
# >> processing No 288 in summer anthems
#
# >> processing No 289 in summer anthems
#
# >> processing No 290 in summer anthems
#
# >> processing No 291 in summer anthems
#
# >> processing No 292 in summer anthems
#
# >> processing No 293 in summer anthems
#
# >> processing No 294 in summer anthems
#
# >> processing No 295 in summer anthems
#
# >> processing No 296 in summer anthems
#
# >> processing No 297 in summer anthems
#
# >> processing No 298 in summer anthems
#
# >> processing No 299 in summer anthems
#
# >> processing No 300 in summer anthems
#
# >> processing No 301 in summer anthems
#
# >> processing No 302 in summer anthems
#
# >> processing No 303 in summer anthems
#
# >> processing No 304 in summer anthems
#
# >> processing No 305 in summer anthems
#
# >> processing No 306 in summer anthems
#
# >> processing No 307 in summer anthems
#
# >> processing No 308 in summer anthems
#
# >> processing No 309 in summer anthems
#
# >> processing No 310 in summer anthems
#
# >> processing No 311 in summer anthems
#
# >> processing No 312 in summer anthems
#
# >> processing No 313 in summer anthems
#
# >> processing No 314 in summer anthems
#
# >> processing No 315 in summer anthems
#
# >> processing No 316 in summer anthems
#
# >> processing No 317 in summer anthems
#
# >> processing No 318 in summer anthems
#
# >> processing No 319 in summer anthems
#
# >> processing No 320 in summer anthems
#
# >> processing No 321 in summer anthems
#
# >> processing No 322 in summer anthems
#
# >> processing No 323 in summer anthems
#
# >> processing No 324 in summer anthems
#
# >> processing No 325 in summer anthems
#
# >> processing No 326 in summer anthems
#
# >> processing No 327 in summer anthems
#
# >> processing No 328 in summer anthems
#
# >> processing No 329 in summer anthems
#
# >> processing No 330 in summer anthems
#
# >> processing No 331 in summer anthems
#
# >> processing No 332 in summer anthems
#
# >> processing No 333 in summer anthems
#
# >> processing No 334 in summer anthems
#
# >> processing No 335 in summer anthems
#
# >> processing No 336 in summer anthems
#
# >> processing No 337 in summer anthems
#
# >> processing No 338 in summer anthems
#
# >> processing No 339 in summer anthems
#
# >> processing No 340 in summer anthems
#
# >> processing No 341 in summer anthems
#
# >> processing No 342 in summer anthems
#
# >> processing No 343 in summer anthems
#
# >> processing No 344 in summer anthems
#
# >> processing No 345 in summer anthems
#
# >> processing No 346 in summer anthems
#
# >> processing No 347 in summer anthems
#
# >> processing No 348 in summer anthems
#
# >> processing No 349 in summer anthems
#
# >> processing No 350 in summer anthems
#
# >> processing No 351 in summer anthems
#
# >> processing No 352 in summer anthems
#
# >> processing No 353 in summer anthems
#
# >> processing No 354 in summer anthems
#
# >> processing No 355 in summer anthems
#
# >> processing No 356 in summer anthems
#
# >> processing No 357 in summer anthems
#
# >> processing No 358 in summer anthems
#
# >> processing No 359 in summer anthems
#
# >> processing No 360 in summer anthems
#
# >> processing No 361 in summer anthems
#
# >> processing No 362 in summer anthems
#
# >> processing No 363 in summer anthems
#
# >> processing No 364 in summer anthems
#
# >> processing No 365 in summer anthems
#
# >> processing No 366 in summer anthems
#
# >> processing No 367 in summer anthems
#
# >> processing No 368 in summer anthems
#
# >> processing No 369 in summer anthems
#
# >> processing No 370 in summer anthems
#
# >> processing No 371 in summer anthems
#
# >> processing No 372 in summer anthems
#
# >> processing No 373 in summer anthems
#
# >> processing No 374 in summer anthems
#
# >> processing No 375 in summer anthems
#
# >> processing No 376 in summer anthems
#
# >> processing No 377 in summer anthems
#
# >> processing No 378 in summer anthems
#
# >> processing No 379 in summer anthems
#
# >> processing No 380 in summer anthems
#
# >> processing No 381 in summer anthems
#
# >> processing No 382 in summer anthems
#
# >> processing No 383 in summer anthems
#
# >> processing No 384 in summer anthems
#
# >> processing No 385 in summer anthems
#
# >> processing No 386 in summer anthems
#
# >> processing No 387 in summer anthems
#
# >> processing No 388 in summer anthems
#
# >> processing No 389 in summer anthems
#
# >> processing No 390 in summer anthems
#
# >> processing No 391 in summer anthems
#
# >> processing No 392 in summer anthems
#
# >> processing No 393 in summer anthems
#
# >> processing No 394 in summer anthems
#
# >> processing No 395 in summer anthems
#
# >> processing No 396 in summer anthems
#
# >> processing No 397 in summer anthems
#
# >> processing No 398 in summer anthems
#
# >> processing No 399 in summer anthems
#
# >> processing No 400 in summer anthems
#
# >> processing No 401 in summer anthems
#
# >> processing No 402 in summer anthems
#
# >> processing No 403 in summer anthems
# >> processing No 404 in summer anthems
#
# >> processing No 405 in summer anthems
#
# >> processing No 406 in summer anthems
#
# >> processing No 407 in summer anthems
#
# >> processing No 408 in summer anthems
#
# >> processing No 409 in summer anthems
#
# >> processing No 410 in summer anthems
#
# >> processing No 411 in summer anthems
#
# >> processing No 412 in summer anthems
#
# >> processing No 413 in summer anthems
#
# >> processing No 414 in summer anthems
#
# >> processing No 415 in summer anthems
#
# >> processing No 416 in summer anthems
#
# >> processing No 417 in summer anthems
#
# >> processing No 418 in summer anthems
#
# >> processing No 419 in summer anthems
#
# >> processing No 420 in summer anthems
#
# >> processing No 421 in summer anthems
#
# >> processing No 422 in summer anthems
#
# >> processing No 423 in summer anthems
#
# >> processing No 424 in summer anthems
#
# >> processing No 425 in summer anthems
#
# >> processing No 426 in summer anthems
#
# >> processing No 427 in summer anthems
#
# >> processing No 428 in summer anthems
#
# >> processing No 429 in summer anthems
#
# >> processing No 430 in summer anthems
#
# >> processing No 431 in summer anthems
#
# >> processing No 432 in summer anthems
#
# >> processing No 433 in summer anthems

# %%
#Analyze sentiment of SUMMER songs

danceability = []
energy = []
acousticness = []
valence = []
tempo = []
instru = []

for uri in summer_uri_list:
    features = spotify.audio_features(uri)[0]
    try:
        danceability.append(features['danceability'])
    except: 
        danceability.append('N/A')
    try:
        energy.append(features['energy'])
    except:
        energy.append('N/A')
    try:
        valence.append(features['valence'])
    except:
        valence.append('N/A')
    try:
        acousticness.append(features['acousticness'])
    except:
        acousticness.append('N/A')
    try:
        tempo.append(features['tempo'])
    except:
        tempo.append('N/A')
    try:
        instru.append(features['instrumentalness'])
    except:
        instru.append('N/A')

# %%
# Store all SUMMER data

summer_df = pd.DataFrame(list(zip(summer_songs, summer_artists, summer_uri_list, summer_chart_date, summer_lyrics, summer_sentiments, 
                                  danceability, energy, acousticness, valence, tempo, instru)), 
                  columns = ['Summer Anthem', 
                            'Artist',
                            'Song URI',
                            'Date',
                            'Lyrics',
                            'Sentiment',
                            'Danceability',
                            'Energy',
                            'Acousticness',
                            'Valence',
                            'Tempo',
                            'Instrumentalness'])
summer_df

# %%
# Retrieve audio features of WINTER songs

winter_uri_list = []
winter_lyrics = []
winter_sentiments = []
winter_year = []

n = 0    

for song, artist in zip(winter_songs, winter_artists):
    
    #Retrieve song URI
    query = spotify.search(f'{song} {artist}')
    try:
        song_uri = query['tracks']['items'][0]['uri']
    except:
        song_uri = 'N/A'
    winter_uri_list.append(song_uri)
    n +=1
    
    #Retrieve and clean lyrics
    url = f"https://api.lyrics.ovh/v1/{artist}/{song}"
    try:
        words = requests.get(url).json()
        words = words['lyrics']
        words = words.replace('\n', ' ')
    except: 
        words = 'N/A'

    #Analyze sentiment of lyrics
    results = analyzer.polarity_scores(words)
    compound = results["compound"]
    
    winter_sentiments.append(compound)
        
    winter_lyrics.append(words)
    
    time.sleep(.3)
    
    print(('\n>> Processing No '+ str(n) + ' in winter anthems '))

# %%
#Analyze sentiment of WINTER songs

danceability = []
energy = []
acousticness = []
valence = []
tempo = []
instru = []

for uri in winter_uri_list:
    features = spotify.audio_features(uri)[0]
    try:
        danceability.append(features['danceability'])
    except: 
        danceability.append('N/A')
    try:
        energy.append(features['energy'])
    except:
        energy.append('N/A')
    try:
        valence.append(features['valence'])
    except:
        valence.append('N/A')
    try:
        acousticness.append(features['acousticness'])
    except:
        acousticness.append('N/A')
    try:
        tempo.append(features['tempo'])
    except:
        tempo.append('N/A')
    try:
        instru.append(features['instrumentalness'])
    except:
        instru.append('N/A')

# %%
# Store all WINTER data
winter_df = pd.DataFrame(list(zip(winter_songs, winter_artists, winter_uri_list, winter_chart_date, winter_lyrics, winter_sentiments,
                                  danceability, energy, acousticness, valence, tempo, instru)), 
                  columns = ['Winter Anthem', 
                            'Artist',
                            'Song URI',
                            'Date',
                            'Lyrics',
                            'Sentiment',
                            'Danceability',
                            'Energy',
                            'Acousticness',
                            'Valence',
                            'Tempo',
                            'Instrumentalness'])
winter_df

# %%
winter_df.to_csv("Winter Hot 100.csv")
summer_df.to_csv("Summer Hot 100.csv")
